# %% [markdown]
# # Homework 01: Surveys, Syllabus, and Reading
#
# ### <p style="text-align: right;"> Zhiqiang Ni </p>

# %% [markdown]
# Welcome to your first homework assignment! This assignment will help you set up the necessary tools and familiarize yourself with course materials essential for your success in this Data Science course.
#
# ## Objectives
# By completing this homework, you will:
#
# * Familiarize yourself with course expectations and policies
# * Set up essential tools for the course
# * Assess your current Python knowledge
# * Begin engaging with course content

# %% [markdown]
# ## Part 1. Read Course Materials (10 points)
#
# There are three important documents for this course. In this problem you will find them, read them and summarize them.
#
# 🗒️ **Task:** Read the course syllabus (available in Teams and D2L as a PDF). In a new markdown cell, summarize the portions of the syllabus regarding attendance and late assignments.

# %% [markdown]
# Attendance is mandatory, since there are ICAs which are done in small groups and are due at the end of the class session unless otherwise specified, If you don't show up only will receive 1 point for submission, No late ICAs will be accepted.
#
# Homework assignments will be accepted up to 48 hours past the original due date. 10% penalty is applied if an assignment is submitted within 24 hours of the deadline, even if it is just one minute late. 20% deduction is applied for submissions in the 24-48 hour window. other than these times it will not be accepted.

# %% [markdown]
# 🗒️ **Task:** Read the AI policy (PDF). In a new markdown cell, summarize what you need to do to do when you use AI for an assignment.

# %% [markdown]
# Don't have the AI do everything, work must show that you used your own brain. If the work is all from AI, it will fail.
#
# must clearly state that you used an AI tool and list its name, version, and the date you used it.
#
# AI can be wrong, so you are responsible for making sure everything is correct.
#
# For coding, you must understand every line of code. For writing, use AI to get ideas, but use your own voice.

# %% [markdown]
# 🗒️ **Task:** Read the AI guide to best practices (PDF). Also in a new markdown cell, give us some feedback on your experiences using AI in the past. How well did it work? What strategies have you developed for yourself, if any?

# %% [markdown]
# it not really good at explaining the how to solve the math problem, but it works really well for coding.

# %% [markdown]
# ## Part 2. GitHub Setup (10 points)
#
# You will use GitHub for your two projects. In addition to learning an important data science tool, this will allow you to retain all of your work beyond this course and share with people around the world.
#
# 🗒️ **Task:**
# * Create a GitHub account (if you don't already have one)
# * If you are not already familiar with GH:
#   * [this](https://www.youtube.com/watch?v=tRZGeaHPoaw) is a great video - watch it slowly over the next week or so
#   * and, you can complete the GitHub Hello World guide: https://guides.github.com/activities/hello-world/
# * Create a new repository for this course and call it `cmse830_fds`
#
# In the markdown cell below add your github username and repo name.

# %% [markdown]
# https://gitlab.msu.edu/nizhiqia/cmse830_fds (professor said gitlab is also ok)

# %% [markdown]
# ## Part 3. Initial and Python Surveys (10 points)
#
# Complete the [initial survey](https://forms.office.com/r/GNHk4SgyNg) _if you haven't already_.
#
# Complete the Python coding knowledge survey: [click here](https://forms.office.com/r/c9exRxM4aV)
#
# Put a statement in a markdown cell that you have completed both of these.

# %% [markdown]
# Done

# %% [markdown]
# ## Part 4. Textbook Reading (10 points)
#
# 🗒️ **Task:** Read Chapter 1 of "_Thinking Clearly with Data_"
# * In a markdown cell, give a very high-level overview of the book
#    * what are its goals and how are those goals organized?
#    * what can you hope to get out of this book?
# * Write a brief summary (200-300 words) of the key points from Chapter 1

# %% [markdown]
# The book's goal is to help us use evidence to make better decisions in our personal and professional lives, become a more informed person. The authors believe that with patience, effort, and a determination to prioritize clear thinking over technical details, anyone can become a wise consumer of quantitative information.
# The book is organized in four parts: Part 1 establishes some shared language clarifying what we mean by correlation and causation and what each is useful for. Part 2 discusses how we can tell whether a statistical relationship is genuine. Part 3 discusses
# how we can tell if that relationship reflects a causal phenomenon or not. And part 4 discusses how we should and shouldn't incorporate quantitative information into our decision making.
#
# Those are what you will get out this book:
# <ul>
# <li>Learning to think clearly and conceptually about quantitative information is important for lots of reasons, even if you have no interest in a career as a data analyst.</li>
# <li>Even well-trained people often make crucial errors with data.</li>
# <li>Thinking and data are complements, not substitutes.</li>
# <li>The skills you learn in this book will help you use evidence to make better decisions in your personal and professional life and be a more thoughtful and well-informed citizen.</li>
# </ul>
#
# Chapter 1 talked about in today’s world we are surrounded by data, the author give us three examples. First is Abe, a baby doctors thought had celiac disease because of a test they said was 80% accurate. But when looking closer at false positives and negatives, the test was very unreliable, and Abe was actually fine. Second is civil resistance: studies showed non-violent protests seemed more successful, but that may be because those protests already had more public support, not because non-violence caused the results. The third is broken windows policing in New York. Crime dropped when police focused on small crimes, but the drop may have been from reversion to the mean, not the policing strategy itself. Despite a lot of data around us, but is still hard to learn to think clearly about what those number mean. Many classes teach formulas and technical details, but people often just memorize them instead of really understand. The authors argue that asking the right questions and comparing the right things is the most important part of using data. Once you can think clearly, the technical part will follow. The key point is that data alone cannot guarantee clear thinking. Experts and our own intuition can still be wrong.

# %% [markdown]
# ---
# ## Part 5. Streamlit Setup and Test (10 points)
#
# 🗒️ **Task:** We will develop web apps using [Streamlit](https://streamlit.io) throughout the semester and your projects will use this tool.
#
# Install Streamlit on your computer, follow the installation guide: https://docs.streamlit.io/library/get-started/installation
#
# Note that Streamlit is run from the command line. [Read this.](https://docs.streamlit.io/get-started/fundamentals/main-concepts) Bookmark this documentation for later in the semester.
#
# Let us know if you have any issues with this.
#
# Next, create .py files with the following two codes and ensure that these run on your computer. It is not necessary that you understand what they do; the goal here is:
#
# ```python
# # Streamlit Code 1
#
# import streamlit as st
#
# st.write("Hello World!")
# ```
#
# ```python
# # Streamlit Code 2
#
# import streamlit as st
# import pandas as pd
# import numpy as np
#
# chart_data = pd.DataFrame(
#    np.random.randn(20, 3),
#    columns=['a', 'b', 'c'])
#
# st.line_chart(chart_data)
# ```
#
# 1. to get Streamlit operational on your computer, and let us know where the problems are,
# 2. and, see what Streamlit does and how it functions.
#
# Include screen shots to show that you got this to work.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image1 = mpimg.imread('image/1.png')
image2 = mpimg.imread('image/2.png')
image3 = mpimg.imread('image/3.png')
image4 = mpimg.imread('image/4.png')

fig, axs = plt.subplots(2, 2, figsize=(15, 15))

axs[0, 0].imshow(image1)
axs[0, 0].set_title('Command Line Code 1')
axs[0, 0].axis('off')

axs[0, 1].imshow(image2)
axs[0, 1].set_title('Result 1')
axs[0, 1].axis('off')

axs[1, 0].imshow(image3)
axs[1, 0].set_title('Command Line Code 2')
axs[1, 0].axis('off')

axs[1, 1].imshow(image4)
axs[1, 1].set_title('Result 2')
axs[1, 1].axis('off')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Congratulations, you're done!
#
# Submit this assignment by uploading your notebook to the course Desire2Learn web page.  Go to the "Homework" folder, find the appropriate submission link, and upload everything there. Make sure your name is on it!

# %% [markdown]
# &#169; Copyright 2023, Department of Computational Mathematics, Science and Engineering at Michigan State University.
